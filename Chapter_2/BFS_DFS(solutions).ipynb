# %%
# import modules and packages
from searches import bfs, dfs, all_paths_search

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
# To do: Represent the graph above as a Python dictionary
graph1 = {1: [2, 3],
         2: [1, 3, 4],
         3: [1, 2, 5],
         4: [2, 5],
         5: [3, 4, 7],
         6: [7, 8],
         7: [5, 6, 8],
         8: [6, 7]}

# %%
# Use BFS and DFS to find the path from initial state (1) to goal state (8)
bfs_path = bfs(graph1, start=2, end=7)
dfs_path = dfs(graph1, start=2, end=7)

print(f"BFS path: {bfs_path}")
print(f"DFS path: {dfs_path}")
# Out:
# BFS path: [2, 3, 5, 7]
# DFS path: [2, 4, 5, 7]

# %%
all_paths = all_paths_search(graph1, start=1, end=8)
print(f"All paths: {all_paths}")
# Out:
# All paths: [[1, 3, 5, 7, 8], [1, 2, 3, 5, 7, 8], [1, 2, 4, 5, 7, 8], [1, 3, 5, 7, 6, 8], [1, 2, 3, 5, 7, 6, 8], [1, 2, 4, 5, 7, 6, 8], [1, 3, 2, 4, 5, 7, 8], [1, 3, 2, 4, 5, 7, 6, 8]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Labelled state                         |  Graph
# :-------------------------------------:|:---------------------------------:
# ![image-2.png](attachment:image-2.png) | ![image.png](attachment:image.png)

# %%
# To do: Represent the maze above as a graph and subsequently as a Python dictionary
graph2 = {1: [3],
         2: [5],
         3: [1, 4],
         4: [3, 5, 6],
         5: [2, 4, 7],
         6: [4, 7],
         7: [5, 6]}

# %%
# Solve the maze using BFS and DFS
bfs_path = bfs(graph2, start=1, end=7)
dfs_path = dfs(graph2, start=1, end=7)

print(f"BFS path: {bfs_path}")
print(f"DFS path: {dfs_path}")

all_paths = all_paths_search(graph2, start=1, end=7)
print(f"All paths: {all_paths}")
# Out:
# BFS path: [1, 3, 4, 5, 7]
# DFS path: [1, 3, 4, 6, 7]
# All paths: [[1, 3, 4, 5, 7], [1, 3, 4, 6, 7]]

# %% [markdown]
# BFS & DFS Exercise
# - Use BFS and DFS to find the path to reach the goal for the maze shown in the following figure:
# ![image.png](attachment:image.png)
# - In addition, find all the available paths for the player to reach the goal.
# - Provide your solutions in a Jupyter notebook.

# %% [markdown]
# Labelled state                    | Graph
# :--------------------------------:|:-------------------------------------:
# ![image.png](attachment:image.png)|![image-2.png](attachment:image-2.png)

# %%
graph3 = {1: [2, 5],
          2: [1, 3],
          3: [2, 4, 6],
          4: [3],
          5: [1, 7],
          6: [3, 9],
          7: [5, 8],
          8: [7, 9],
          9: [6, 8, 10],
          10: [9]}

bfs_path = bfs(graph3, start=5, end=4)
dfs_path = dfs(graph3, start=5, end=4)

print(f"BFS path: {bfs_path}")
print(f"DFS path: {dfs_path}")

all_paths = all_paths_search(graph3, start=5, end=4)
print(f"All paths: {all_paths}")
# Out:
# BFS path: [5, 1, 2, 3, 4]
# DFS path: [5, 7, 8, 9, 6, 3, 4]
# All paths: [[5, 1, 2, 3, 4], [5, 7, 8, 9, 6, 3, 4]]
