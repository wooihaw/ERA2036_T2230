# %%
# import functions from module
from searches import bfs, dfs, all_paths_search

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
# To do: Represent the graph above as a Python dictionary

# %%
# Use BFS and DFS to find the path from initial state (1) to goal state (8)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# To do: Represent the maze above as a graph and subsequently as a Python dictionary

# %%
# Solve the maze using BFS and DFS
